# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span></li><li><span><a href="#Вывод-по-разделу-&quot;Изучение-данных-из-файла&quot;" data-toc-modified-id="Вывод-по-разделу-&quot;Изучение-данных-из-файла&quot;-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Вывод по разделу "Изучение данных из файла"</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод-по-разделу-&quot;Предобработка-данных&quot;" data-toc-modified-id="Вывод-по-разделу-&quot;Предобработка-данных&quot;-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод по разделу "Предобработка данных"</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Вывод-по-разделу-&quot;Исследовательский-Анализ-данных&quot;" data-toc-modified-id="Вывод-по-разделу-&quot;Исследовательский-Анализ-данных&quot;-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Вывод по разделу "Исследовательский Анализ данных"</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span></li><li><span><a href="#Вывод-по-разделу" data-toc-modified-id="Вывод-по-разделу-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Вывод по разделу</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод-по-разделу" data-toc-modified-id="Вывод-по-разделу-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод по разделу</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Вывод-по-разделу" data-toc-modified-id="Вывод-по-разделу-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Вывод по разделу</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Производим чтение файла с данными в переменную
try:
    df=pd.read_csv('/datasets/real_estate_data.csv',sep='\t')
except:
    df=pd.read_csv(r'C:\Users\Admin\Desktop\Яндек-проекты\Исследовательский анализ данных\task_csv\real_estate_data.csv',sep='\t')

# %%
#Вывод информации о массиве на экран  
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
display(df.head(5))
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
display(df.tail(5))
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 23694             3.7           5.0         73.3      3          NaN  ...
# 23695             NaN           5.0         38.0      4          NaN  ...
# 23696             NaN           3.0         29.7      1          NaN  ...
# 23697             3.0          17.0          NaN     12          NaN  ...
# 23698             2.5           5.0         12.3      1          NaN  ...
#
#        kitchen_area  balcony        locality_name  airports_nearest  \
# ...

# %%
#добавляем 'record_id'
df['record_id']=df.index

# %%
#проверка на наличие пропусков
display('Пропусков по полям:')
propusk=pd.DataFrame(df.isna().sum())
propusk.columns=['isna_count']
propusk['isna_percentage']=propusk['isna_count']/23699*100
display(propusk.sort_values(by='isna_percentage',ascending=False))
# Out:
# 'Пропусков по полям:'
#                       isna_count  isna_percentage
# is_apartment               20924        88.290645
# parks_nearest              15620        65.909954
# ponds_nearest              14589        61.559559
# balcony                    11519        48.605426
# ceiling_height              9195        38.799105
# airports_nearest            5542        23.384953
# cityCenters_nearest         5519        23.287902
# ponds_around3000            5518        23.283683
# parks_around3000            5518        23.283683
# days_exposition             3181        13.422507
# kitchen_area                2278         9.612220
# living_area                 1903         8.029875
# floors_total                  86         0.362885
# locality_name                 49         0.206760
# total_images                   0         0.000000
# open_plan                      0         0.000000
# last_price                     0         0.000000
# ...

# %%
propusk['isna_percentage'].sort_values(ascending=False).plot(kind='bar',grid=True).set_title(
'Количество пропусков по полям, в процентах')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - `is_apartment` (апартаменты, булев тип):
#   - Пропущенные значения заменяем на `False` (ложь), так как отсутствие информации означает, что это не апартаменты.
#   - Изменяем тип данных на булев тип.
#
# - `parks_nearest` (расстояние до ближайшего парка, м):
#   - Пропущенные значения заменяем на -1, чтобы указать отсутствие информации о ближайшем парке.
#   - Данные из автоматизированной системы, что может объяснить большие значения.
#
# - `ponds_nearest` (расстояние до ближайшего водоёма, м):
#   - Пропущенные значения также заменяем на -1, чтобы указать отсутствие информации о ближайшем водоёме.
#   - Данные из автоматизированной системы, что может объяснить большие значения.
#
# - `balcony` (число балконов):
#   - Преобразуем в целочисленный тип данных и пропущенные значения заменяем на 0, что означает отсутствие балкона.
#
# - `ceiling_height` (высота потолков, м):
#   - Можно заменить на -1, чтобы указать отсутствие информации, или провести анализ с группировкой по другим параметрам (количество комнат, площадь и т. д.).
#
# - `airports_nearest` (расстояние до ближайшего аэропорта, м):
#   - Пропущенные значения заменяем на -1, так как расстояние до ближайшего аэропорта может быть значительным.
#
# - `cityCenters_nearest` (расстояние до центра города, м):
#   - Также заменяем на -1, так как ближайший центр города может находиться далеко.
#
# - `ponds_around3000` (число водоёмов в радиусе 3 км):
#   - Пропущенные значения заменяем на 0, чтобы указать отсутствие ближайших водоёмов.
#
# - `parks_around3000` (число парков в радиусе 3 км):
#   - Также заменяем на 0, чтобы указать отсутствие ближайших парков.
#
# - `days_exposition` (сколько дней было размещено объявление):
#   - Пропущенные значения заменяем на -1, чтобы указать отсутствие информации о днях размещения.
#
# - `kitchen_area` (площадь кухни, м²):
#   - Можно рассмотреть опции: либо удалить данные с пропущенными значениями, либо заменить на -1.
#
# - `living_area` (жилая площадь, м²):
#   - Также можно рассмотреть опции: либо удалить данные с пропущенными значениями, либо заменить на -1.
#
# - `floors_total` (всего этажей в доме):
#   - Данный параметр можно рассмотреть на предмет удаления из анализа, так как он несет мало информации и может быть несостоятельным.

# %%
display('явных дубликатов', df.duplicated().sum()) #посчет явных дубликатов
# Out:
# 'явных дубликатов'
# 0

# %% [markdown]
# Рассмотрим типы данных

# %%
df.dtypes
# Out:
# total_images              int64
# last_price              float64
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total            float64
# living_area             float64
# floor                     int64
# is_apartment             object
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                 float64
# locality_name            object
# airports_nearest        float64
# cityCenters_nearest     float64
# parks_around3000        float64
# parks_nearest           float64
# ponds_around3000        float64
# ponds_nearest           float64
# days_exposition         float64
# record_id                 int64
# dtype: object

# %% [markdown]
# - `is_apartment` (апартаменты, булев тип):
#   - Неверный формат, должен быть логическим (`bool`).
#
# - `floors_total` (всего этажей в доме):
#   - Неверный формат, должен быть целочисленным (`int64`).
#
# - `first_day_exposition` (первый день публикации объявления):
#   - Неверный формат, должен быть либо целочисленным (`int64`), представляющим количество дней, либо форматом даты и времени (`datetime`).
#
# - `balcony` (число балконов):
#   - Неверный формат, должен быть целочисленным (`int64`).
#
# - `parks_around3000` (число парков в радиусе 3 км):
#   - Неверный формат, должен быть целочисленным (`int64`).
#
# - `parks_nearest` (расстояние до ближайшего парка, м):
#   - Неверный формат, должен быть целочисленным (`int64`).
#
# - `ponds_around3000` (число водоёмов в радиусе 3 км):
#   - Неверный формат, должен быть целочисленным (`int64`).
#
# - `ponds_nearest` (расстояние до ближайшего водоёма, м):
#   - Неверный формат, должен быть целочисленным (`int64`).
#
# - `days_exposition` (сколько дней было размещено объявление):
#   - Неверный формат, должен быть целочисленным (`int64`).

# %% [markdown]
# ## Вывод по разделу "Изучение данных из файла"

# %% [markdown]
# **В исходном массиве данных, состоящем из 23699 строк и 23 столбцов, отсутствуют явные дубликаты записей. Однако в некоторых столбцах присутствуют пропуски данных.**
#
# **План предобработки данных:**
#
# 1. `is_apartment` — столбец, отвечающий за тип недвижимости (апартаменты), имеет булев тип данных. Пропущенные значения заменяются на False (нулевые значения), и меняется тип данных на булевый.
#
# 2. `parks_nearest` — столбец, содержащий расстояние до ближайшего парка в метрах (м). Эти данные получены автоматически из системы и могут указывать на то, что ближайший парк находится слишком далеко. Пропущенные значения заменяются на -1, чтобы не искажать общую картину. Замена на 0 могла бы исказить результаты анализа.
#
# 3. `ponds_nearest` — столбец, содержащий расстояние до ближайшего водоема в метрах (м). Аналогично, если ближайший водоем находится слишком далеко, пропущенные значения заменяются на -1.
#
# 4. `balcony` — столбец, указывающий количество балконов. Для удобства анализа, переводим данные в целочисленный тип и пропущенные значения заменяем на 0, что означает отсутствие балкона.
#
# 5. `ceiling_height` — высота потолков в метрах (м). Пропущенные значения можно заменить на -1 или на медианные значения, учитывая группировку по количеству комнат, общей площади и жилой площади. Однако этот столбец может быть исключен из анализа, так как пользователи могут не указывать высоту потолков.
#
# 6. `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м). Пропущенные значения заменяются на -1, предполагая, что ближайший аэропорт находится слишком далеко.
#
# 7. `cityCenters_nearest` — расстояние до центра города в метрах (м). Если данные были получены автоматически и указывают на большое расстояние до центра, пропущенные значения также заменяются на -1.
#
# 8. `ponds_around3000` и `parks_around3000` — столбцы, указывающие количество водоемов и парков в радиусе 3 км соответственно. Пропущенные значения заменяются на 0.
#
# 9. `days_exposition` — количество дней, в течение которых объявление было размещено (от публикации до снятия). Пропущенные значения заменяются на -1.
#
# 10. `kitchen_area` и `living_area` — площади кухни и жилой площади в квадратных метрах (м²). Пропущенные значения можно либо удалить, либо заменить на -1.
#
# 11. `floors_total` — общее количество этажей в доме. Этот столбец можно исключить из анализа, так как он несет небольшую информационную ценность.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Убираем научный формат

# %%
pd.options.display.float_format = '{:.3f}'.format # Убираем высокую точность

# %%
#Разберемся с заголовками
display(df.columns)
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition', 'record_id'],
#       dtype='object')

# %% [markdown]
# 'cityCenters_nearest' -стиль, исправим

# %%
df = df.rename(columns={ 
'cityCenters_nearest': 'city_сenters_nearest', 
 } 
              )

# %% [markdown]
# Работа с пропусками:

# %%
display(df.isna().sum()) #Отображаем поля с пропусками
#Проценты пропущенных значений
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_сenters_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# record_id                   0
# dtype: int64

# %% [markdown]
# Безопасно переводим значения в числовые для столбцов, содержащих числовое значение и фиксим date_time

# %%
df['ceiling_height']=pd.to_numeric(df['ceiling_height'],errors='coerce')
df['last_price']=pd.to_numeric(df['last_price'],errors='coerce')
df['total_area']=pd.to_numeric(df['total_area'],errors='coerce')
df['floors_total']=pd.to_numeric(df['floors_total'],errors='coerce')
df['living_area']=pd.to_numeric(df['living_area'],errors='coerce')
df['kitchen_area']=pd.to_numeric(df['kitchen_area'],errors='coerce')
df['balcony']=pd.to_numeric(df['balcony'],errors='coerce')
df['airports_nearest']=pd.to_numeric(df['airports_nearest'],errors='coerce')
df['city_сenters_nearest']=pd.to_numeric(df['city_сenters_nearest'],errors='coerce')
df['parks_around3000']=pd.to_numeric(df['parks_around3000'],errors='coerce')
df['parks_nearest']=pd.to_numeric(df['parks_nearest'],errors='coerce')
df['ponds_around3000']=pd.to_numeric(df['ponds_around3000'],errors='coerce')
df['ponds_nearest']=pd.to_numeric(df['ponds_nearest'],errors='coerce')
df['days_exposition']=pd.to_numeric(df['days_exposition'],errors='coerce')
df['is_apartment']=pd.to_numeric(df['is_apartment'],errors='coerce')
#Фиксим date_time
df['first_day_exposition']=pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
df.dtypes
# Out:
# total_images                     int64
# last_price                     float64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                   float64
# living_area                    float64
# floor                            int64
# is_apartment                   float64
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                        float64
# locality_name                   object
# airports_nearest               float64
# city_сenters_nearest           float64
# parks_around3000               float64
# parks_nearest                  float64
# ponds_around3000               float64
# ponds_nearest                  float64
# days_exposition                float64
# record_id                        int64
# dtype: object

# %% [markdown]
# Заполняем пропущенные значения по плану

# %% [markdown]
# - `is_apartment`: Этот столбец содержит информацию о том, является ли недвижимость апартаментами. Пропуски заменяем на значение False и меняем тип данных на булев (bool).
#
# - `parks_nearest`: В данном столбце содержится информация о расстоянии до ближайшего парка. Поскольку эти данные получены из автоматизированной системы, пропущенные значения заменяем на -1, так как предполагается, что ближайший парк находится слишком далеко. Замена на 0 может исказить картину.
#
# - `ponds_nearest`: В этом столбце указано расстояние до ближайшего водоема. Аналогично паркам, пропущенные значения заменяем на -1.
#
# - `balcony`: Столбец содержит информацию о количестве балконов. Мы переводим этот столбец в целочисленный тип данных (int) и заменяем пропуски на 0, предполагая, что отсутствие информации о балконах означает их отсутствие.
#
# - `ceiling_height`: В этом столбце указана высота потолков в метрах. Мы заменяем пропущенные значения на -1 или на медианные значения, рассчитанные по группам (например, по числу комнат, площади, жилой площади). Этот столбец также можно исключить из анализа, так как пользователь может не знать высоту потолков.
#
# - `airports_nearest`: В данном столбце указано расстояние до ближайшего аэропорта в метрах. Пропущенные значения заменяем на -1, предполагая, что ближайший аэропорт слишком далеко.
#
# - `cityCenters_nearest`: Этот столбец содержит информацию о расстоянии до центра города в метрах. Предполагая, что ближайший центр города находится слишком далеко, заменяем пропущенные значения на -1.
#
# - `ponds_around3000`: Здесь указано количество водоемов в радиусе 3 км. Пропущенные значения заменяем на 0.
#
# - `parks_around3000`: Этот столбец содержит информацию о количестве парков в радиусе 3 км. Пропущенные значения также заменяем на 0.
#
# - `days_exposition`: В данном столбце указано, сколько дней было размещено объявление (от публикации до снятия). Пропущенные значения заменяем на -1.
#
# - `kitchen_area` и `living_area`: Эти столбцы содержат информацию о площади кухни и жилой площади в квадратных метрах. Можно либо исключить строки с пропущенными значениями, либо заменить их на -1, в зависимости от контекста и задачи анализа.
#
# - `floors_total`: Этот столбец содержит информацию о общем количестве этажей в доме. Пропущенные значения можно либо исключить из анализа, либо заменить на -1.

# %%
#Заполняем is_apartment и balcony 0

df['is_apartment']=df['is_apartment'].fillna(0)
#Заполняем balcony 0
df['balcony']=df['balcony'].fillna(0)
# Заполняем parks_nearest заменим пропущенные значения на (-1)
df['parks_nearest']=df['parks_nearest'].fillna(-1)
#ponds_nearest — заменим пропущенные значения на (-1)
df['ponds_nearest']=df['ponds_nearest'].fillna(-1)

#ceiling_height — высота потолков (м). Заменяем на -1 
df['ceiling_height']=df['ceiling_height'].fillna(-1)

#airports_nearest — заменяем на -1
df['airports_nearest']=df['airports_nearest'].fillna(-1)

#city_centers_nearest — заменяем на -1
df['city_сenters_nearest']=df['city_сenters_nearest'].fillna(-1)

#ponds_around3000 — число водоёмов в радиусе 3 км - заменяем на -1
df['ponds_around3000']=df['ponds_around3000'].fillna(-1)
#parks_around3000 — число парков в радиусе 3 км - заменяем на -1
df['parks_around3000']=df['parks_around3000'].fillna(-1)

#days_exposition — сколько дней было размещено объявление (от публикации до снятия) заменяем на -1
df['days_exposition']=df['days_exposition'].fillna(-1)
#kitchen_area — площадь кухни в квадратных метрах (м²)- либо дропаем, либо заменяем на -1
df['kitchen_area']=df['kitchen_area'].fillna(-1)
#living_area — жилая площадь в квадратных метрах (м²) - либо дропаем, либо заменяем на -1 floors_total — всего этажей в доме - дропаем
df['living_area']=df['living_area'].fillna(-1)

#floors_total— меняем на -1
df['floors_total']=df['floors_total'].fillna(-1)

#locality_name - меняем на drop

df['locality_name']=df['locality_name'].fillna('drop')

# %%
df.isna().sum()
# Out:
# total_images            0
# last_price              0
# total_area              0
# first_day_exposition    0
# rooms                   0
# ceiling_height          0
# floors_total            0
# living_area             0
# floor                   0
# is_apartment            0
# studio                  0
# open_plan               0
# kitchen_area            0
# balcony                 0
# locality_name           0
# airports_nearest        0
# city_сenters_nearest    0
# parks_around3000        0
# parks_nearest           0
# ponds_around3000        0
# ponds_nearest           0
# days_exposition         0
# record_id               0
# dtype: int64

# %% [markdown]
# Пропуски заполнили, разберемся с дубликатами записей в locality_name

# %%
display('параметры массива',df.shape)
display('количество явных дубликатов в locality_name',df['locality_name'].duplicated().sum())
# Out:
# 'параметры массива'
# (23699, 23)
# 'количество явных дубликатов в locality_name'
# 23334

# %% [markdown]
# Уберем дубликаты, установим причину

# %%
df1=df #Код был заготовлен в предыдущих версиях, поэтому присваиваем df1=df

df1_locality_new=df1['locality_name'].str.split(' ',expand=True)
df1_locality_new['record_id']=df1_locality_new.index
df1_locality_new.columns=['one','two','three','four','five','record_id']
#display(df1_locality_new.count())
#nabor_=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() == True)&(df1_locality_new['two'].str.istitle() == True)&(df1_locality_new['three'].str.istitle() == True)&(df1_locality_new['four'].str.istitle() != True)&(df1_locality_new['five'].str.istitle() != True)])
#Наборы условий, которые необходимо проверить в первую очередь
#display(df1_locality_new.count())
total=23699

#Каскадная проверка
#Общая логика такая: распарсили столбец по сепаратору ' ', проверили по условию на наличие заглавной буквы,дропнули нули,
#получили наборы

#TFFFF
#Первый набор (Столбец one, значение содержит заглавную букву, остальные нет (Город)
nabor1=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() == True)
                             &(df1_locality_new['two'].str.istitle() != True)
                             &(df1_locality_new['three'].str.istitle() != True)
                             &(df1_locality_new['four'].str.istitle() != True)
                             &(df1_locality_new['five'].str.istitle() != True)])
# лок по условию,что данные содержат заглавную букву
# Показываем первый набор
#display(nabor1) #Одно слово 
# Показываем счетчик первого набора
#display(nabor1.count())
#Дропаем нули
nabor1=nabor1.drop(['two','three','four','five'],axis=1)
display(nabor1)
cc=0
cc+=19709
#FTFFF
nabor2=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                             &(df1_locality_new['two'].str.istitle() == True)
                             &(df1_locality_new['three'].str.istitle() != True)
                             &(df1_locality_new['four'].str.istitle() != True)
                             &(df1_locality_new['five'].str.istitle() != True)])
nabor2=nabor2.drop(['one','three','four','five'],axis=1)
display(nabor2)
cc+=2821
#FFTFF
nabor3=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                             &(df1_locality_new['two'].str.istitle() != True)
                             &(df1_locality_new['three'].str.istitle() == True)
                             &(df1_locality_new['four'].str.istitle() != True)
                             &(df1_locality_new['five'].str.istitle() != True)])
nabor3=nabor3.drop(['one','two','four','five'],axis=1)
display(nabor3)
cc+=189
#FFFTF
nabor4=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                             &(df1_locality_new['two'].str.istitle() != True)
                             &(df1_locality_new['three'].str.istitle() != True)
                             &(df1_locality_new['four'].str.istitle() == True)
                             &(df1_locality_new['five'].str.istitle() != True)])
nabor4=nabor4.drop(['one','two','three','five'],axis=1)
display(nabor4)
cc+=296
# Out:
#                    one  record_id
# 0      Санкт-Петербург          0
# 2      Санкт-Петербург          2
# 3      Санкт-Петербург          3
# 4      Санкт-Петербург          4
# 7      Санкт-Петербург          7
# ...                ...        ...
# 23692           Тихвин      23692
# 23693         Петергоф      23693
# 23694  Санкт-Петербург      23694
# 23695            Тосно      23695
# 23697  Санкт-Петербург      23697
#
# [19709 rows x 2 columns]
#                 two  record_id
# 1            Шушары          1
# 6         Парголово          6
# 8            Мурино          8
# 20        Парголово         20
# 22          Кудрово         22
# ...             ...        ...
# 23645   Елизаветино      23645
# 23649     Суходолье      23649
# 23666       Кудрово      23666
# 23683  Дзержинского      23683
# 23696   Рождествено      23696
#
# [2821 rows x 2 columns]
#          three  record_id
# 5      Янино-1          5
# 158    Янино-1        158
# 529    Янино-1        529
# ...

# %%
#FFFFT
nabor5=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)&
                             (df1_locality_new['two'].str.istitle() != True)&
                             (df1_locality_new['three'].str.istitle() != True)
                             &(df1_locality_new['four'].str.istitle() != True)
                             &(df1_locality_new['five'].str.istitle() == True)])

nabor5=nabor5.drop(['one','two','three','four'],axis=1)
display(nabor5)
display(nabor5.count())
cc+=55
# Out:
#                 five  record_id
# 1594       Свердлова       1594
# 1819        Морозова       1819
# 2016       Свердлова       2016
# 2055       Свердлова       2055
# 2208       Свердлова       2208
# 2388       Свердлова       2388
# 2956        Морозова       2956
# 3125       Свердлова       3125
# 3178        Морозова       3178
# 3682        Морозова       3682
# 4252        Морозова       4252
# 4416       Свердлова       4416
# 4633        Морозова       4633
# 4844        Морозова       4844
# 5372       Свердлова       5372
# 7693        Морозова       7693
# 7760        Морозова       7760
# 8118        Морозова       8118
# 8148       Свердлова       8148
# 8229       Свердлова       8229
# 8240       Свердлова       8240
# 8432       Свердлова       8432
# 9512          Вещево       9512
# 9751       Свердлова       9751
# 9830        Морозова       9830
# 10210      Свердлова      10210
# 10405       Морозова      10405
# 10709      Свердлова      10709
# ...

# %% [markdown]
# По поселкам из 1 слова прошлись, переходим к двум словам

# %%
#TTTFF- шагаем зеркально назад по 2 FF
nabor6=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() == True)
                             &(df1_locality_new['two'].str.istitle() == True)
                             &(df1_locality_new['three'].str.istitle() == True)
                             &(df1_locality_new['four'].str.istitle() != True)
                             &(df1_locality_new['five'].str.istitle() != True)])
display(nabor6)
display(nabor6.count())

#TTFFT
nabor7=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() == True)
                             &(df1_locality_new['two'].str.istitle() == True)
                             &(df1_locality_new['three'].str.istitle() != True)
                             &(df1_locality_new['four'].str.istitle() != True)
                             &(df1_locality_new['five'].str.istitle() == True)])
display(nabor7)
display(nabor7.count())

##TFFTT
nabor8=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() == True)
                             &(df1_locality_new['two'].str.istitle() != True)
                             &(df1_locality_new['three'].str.istitle() != True)
                             &(df1_locality_new['four'].str.istitle() == True)
                             &(df1_locality_new['five'].str.istitle() == True)])
display(nabor8)
display(nabor8.count())

#FFTTT
nabor9=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                             &(df1_locality_new['two'].str.istitle() != True)
                             &(df1_locality_new['three'].str.istitle() == True)
                             &(df1_locality_new['four'].str.istitle() == True)
                             &(df1_locality_new['five'].str.istitle() == True)])
display(nabor9)
display(nabor9.count())
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64

# %%
#FFFTT
nabor10=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                              &(df1_locality_new['two'].str.istitle() != True)
                              &(df1_locality_new['three'].str.istitle() != True)
                              &(df1_locality_new['four'].str.istitle() == True)
                              &(df1_locality_new['five'].str.istitle() == True)])
nabor10=nabor10.drop(['one','two','three'],axis=1)
display(nabor10)
display(nabor10.count())
cc+=15

#TFFFT
nabor11=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() == True)
                              &(df1_locality_new['two'].str.istitle() != True)
                              &(df1_locality_new['three'].str.istitle() != True)
                              &(df1_locality_new['four'].str.istitle() != True)
                              &(df1_locality_new['five'].str.istitle() == True)])
display(nabor11)
display(nabor11.count())

#TTFFF
nabor12=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() == True)
                              &(df1_locality_new['two'].str.istitle() == True)
                              &(df1_locality_new['three'].str.istitle() != True)
                              &(df1_locality_new['four'].str.istitle() != True)
                              &(df1_locality_new['five'].str.istitle() != True)])

nabor12=nabor12.drop(['three','four','five'],axis=1)
display(nabor12)
display(nabor12.count())

cc+=299
# Out:
#           four    five  record_id
# 37     Красный     Бор         37
# 514    Красный     Бор        514
# 3971   Красный     Бор       3971
# 4772   Красный     Бор       4772
# 6096   Дружная   Горка       6096
# 7323    Лесная  Поляна       7323
# 7685   Дружная   Горка       7685
# 9544   Красный     Бор       9544
# 12074  Дружная   Горка      12074
# 12311  Красный     Бор      12311
# 17305  Большая   Ижора      17305
# 17689  Дружная   Горка      17689
# 18045  Дружная   Горка      18045
# 18903  Красный     Бор      18903
# 21009  Красный     Бор      21009
# four         15
# five         15
# record_id    15
# dtype: int64
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64
#             one   two  record_id
# 182     Красное  Село        182
# 249     Красное  Село        249
# 306    Сосновый   Бор        306
# ...

# %% [markdown]
# Идем влево, на 4 слова

# %%
#FTTTT
nabor13=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                              &(df1_locality_new['two'].str.istitle() == True)
                              &(df1_locality_new['three'].str.istitle() == True)
                              &(df1_locality_new['four'].str.istitle() == True)
                              &(df1_locality_new['five'].str.istitle() == True)])
#nabor13=nabor13.drop(['two','three','four','five'],axis=1)
display(nabor13)
display(nabor13.count())

nabor14=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                              &(df1_locality_new['two'].str.istitle() != True)
                              &(df1_locality_new['three'].str.istitle() != True)
                              &(df1_locality_new['four'].str.istitle() != True)
                              &(df1_locality_new['five'].str.istitle() != True)])

nabor14=nabor14.drop(['two','three','four','five'],axis=1)
display(nabor14)
display(nabor14.count())
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64
#         one  record_id
# 1097   drop       1097
# 2033   drop       2033
# 2603   drop       2603
# 2632   drop       2632
# 3574   drop       3574
# 4151   drop       4151
# 4189   drop       4189
# 4670   drop       4670
# 5343   drop       5343
# 5707   drop       5707
# 6765   drop       6765
# 7114   drop       7114
# 7330   drop       7330
# 7600   drop       7600
# 8568   drop       8568
# 8986   drop       8986
# 9821   drop       9821
# 10122  drop      10122
# 11248  drop      11248
# 12879  drop      12879
# 12936  drop      12936
# 13223  drop      13223
# 13690  drop      13690
# 14273  drop      14273
# 14342  drop      14342
# 15686  drop      15686
# 15866  drop      15866
# 16499  drop      16499
# 16561  drop      16561
# 16610  drop      16610
# 17535  drop      17535
# ...

# %%
#FTTTF
nabor15=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                              &(df1_locality_new['two'].str.istitle() == True)
                              &(df1_locality_new['three'].str.istitle() == True)
                              &(df1_locality_new['four'].str.istitle() == True)
                              &(df1_locality_new['five'].str.istitle() != True)])
nabor15=nabor15.drop(['one','five'],axis=1)
display(nabor15) 
display(nabor15.count())
cc+=3
# Out:
#              two    three   four  record_id
# 10183       Форт  Красная  Горка      10183
# 19681  Пансионат  Зелёный    Бор      19681
# 19981  Пансионат  Зелёный    Бор      19981
# two          3
# three        3
# four         3
# record_id    3
# dtype: int64

# %% [markdown]
# Проверяем 4 слова, 5 слов с заглавной буквы
#
# Спойлер: их нет

# %% [markdown]
# А теперь причина наблюдаемого явления. Пойдем от обратного.
# Последнее слово с большой буквы

# %%
#FTFTF
nabor16=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                              &(df1_locality_new['two'].str.istitle() == True)
                              &(df1_locality_new['three'].str.istitle() != True)
                              &(df1_locality_new['four'].str.istitle() == True)
                              &(df1_locality_new['five'].str.istitle() != True)])
display(nabor16) 
display(nabor16.count())

#FFTFT
nabor17=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                              &(df1_locality_new['two'].str.istitle() != True)
                              &(df1_locality_new['three'].str.istitle() == True)
                              &(df1_locality_new['four'].str.istitle() != True)
                              &(df1_locality_new['five'].str.istitle() == True)])
display(nabor17) 
display(nabor17.count())

#TTFTF

nabor18=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() == True)
                              &(df1_locality_new['two'].str.istitle() == True)
                              &(df1_locality_new['three'].str.istitle() != True)
                              &(df1_locality_new['four'].str.istitle() == True)
                              &(df1_locality_new['five'].str.istitle() != True)])
display(nabor18) 
display(nabor18.count())

#TFTFT

nabor19=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() == True)
                              &(df1_locality_new['two'].str.istitle() != True)
                              &(df1_locality_new['three'].str.istitle() == True)
                              &(df1_locality_new['four'].str.istitle() != True)
                              &(df1_locality_new['five'].str.istitle() == True)])
display(nabor19) 
display(nabor19.count())

#FTFTT

nabor20=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                              &(df1_locality_new['two'].str.istitle() == True)
                              &(df1_locality_new['three'].str.istitle() != True)
                              &(df1_locality_new['four'].str.istitle() == True)
                              &(df1_locality_new['five'].str.istitle() != True)])
display(nabor20) 
display(nabor20.count())
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# one          0
# two          0
# three        0
# four         0
# five         0
# record_id    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера: ❗️</b>
#
# Если код не помещается в одну строку, рекомендую переносить его на следующую подстроку если мы внутри одного метода пишем код или с помощью обратного слеша, если применяем несколько методов. Так код читается быстрее и понятнее.
#
# </div>

# %%
#FTTFF

nabor21=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                              &(df1_locality_new['two'].str.istitle() == True)
                              &(df1_locality_new['three'].str.istitle() == True)
                              &(df1_locality_new['four'].str.istitle() != True)
                              &(df1_locality_new['five'].str.istitle() != True)])
nabor21=nabor21.drop(['one','four','five'],axis=1)

display(nabor21) 
display(nabor21.count())
cc+=245
# Out:
#             two      three  record_id
# 80        Новое  Девяткино         80
# 227       Новый       Свет        227
# 265       Новое  Девяткино        265
# 313       Новый       Свет        313
# 350       Новое  Девяткино        350
# ...         ...        ...        ...
# 23333     Малое     Верево      23333
# 23339     Новое  Девяткино      23339
# 23411  Борисова      Грива      23411
# 23510     Новое  Девяткино      23510
# 23698     Новый      Учхоз      23698
#
# [245 rows x 3 columns]
# two          245
# three        245
# record_id    245
# dtype: int64

# %%
#FFTTF

nabor22=(df1_locality_new.loc[(df1_locality_new['one'].str.istitle() != True)
                              &(df1_locality_new['two'].str.istitle() != True)
                              &(df1_locality_new['three'].str.istitle() == True)
                              &(df1_locality_new['four'].str.istitle() == True)
                              &(df1_locality_new['five'].str.istitle() != True)])
nabor22=nabor22.drop(['one','two','five'],axis=1)

display(nabor22) 
display(nabor22.count())
cc+=18
# Out:
#            three   four  record_id
# 101        Новая  Ропша        101
# 1009     Большая  Ижора       1009
# 1275     Большая  Ижора       1275
# 2560     Большая  Ижора       2560
# 3974     Большая  Ижора       3974
# 6220     Большая  Ижора       6220
# 9896     Большая  Ижора       9896
# 10102    Большая  Ижора      10102
# 12289    Большая  Ижора      12289
# 13144    Большая  Ижора      13144
# 15543    Большая  Ижора      15543
# 15700    Большая  Ижора      15700
# 16611  Кивеннапа  Север      16611
# 18842    Большая  Ижора      18842
# 19040    Большая  Ижора      19040
# 20675    Большая  Ижора      20675
# 20826    Большая  Ижора      20826
# 21824    Большая  Ижора      21824
# three        18
# four         18
# record_id    18
# dtype: int64

# %% [markdown]
# **Вывод:**
#
#
#
#
# - В данных наблюдается определенная последовательность, включающая некоторые субпризнаки, такие как "пгт," "село," и т.д. Это может указывать на то, что данные были собраны с использованием цикла, вероятно, цикла `for`.
#
# - Обнаружены последовательности из трех идущих подряд слов, что также может быть связано с особенностью сбора данных.
#
# - Присутствие табуляции в данных свидетельствует о наличии специфической структуры.
#
# - Отмечено, что субпризнаки могут следовать друг за другом и между ними нет разрывов, что соответствует структуре данных, созданной с использованием цикла.
#
# - Возможно, схожесть данной структуры с треугольником Паскаля, либо половиной треугольника Паскаля, обращенной вершиной вниз, что может свидетельствовать о специфической логике сбора данных.
#
# Данные аномалии могут повлиять на корректность анализа данных и требуют дополнительной обработки для выделения и структурирования необходимой информации.
#
# Возможно, эти аномалии связаны с логикой сбора данных, и их присутствие может повлиять на корректность анализа. Для дальнейшей обработки данных необходимо провести отбор и структурирование информации, чтобы минимизировать влияние указанных аномалий на аналитические выводы.

# %%
nabor1.columns=['locality_new','record_id']# меняем название колонки на locality_new
display(nabor1)
display('уникальных в наборе 1', nabor1['locality_new'].unique())
# Out:
#           locality_new  record_id
# 0      Санкт-Петербург          0
# 2      Санкт-Петербург          2
# 3      Санкт-Петербург          3
# 4      Санкт-Петербург          4
# 7      Санкт-Петербург          7
# ...                ...        ...
# 23692           Тихвин      23692
# 23693         Петергоф      23693
# 23694  Санкт-Петербург      23694
# 23695            Тосно      23695
# 23697  Санкт-Петербург      23697
#
# [19709 rows x 2 columns]
# 'уникальных в наборе 1'
# array(['Санкт-Петербург', 'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин',
#        'Коммунар', 'Колпино', 'Гатчина', 'Выборг', 'Кронштадт', 'Кировск',
#        'Павловск', 'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск',
#        'Сестрорецк', 'Сясьстрой', 'Сланцы', 'Ивангород', 'Мурино',
#        'Шлиссельбург', 'Никольское', 'Зеленогорск', 'Кудрово', 'Кириши',
#        'Луга', 'Волосово', 'Отрадное', 'Тихвин', 'Тосно', 'Бокситогорск',
# ...

# %%
nabor2['locality_new'] = nabor2['two']
#Дропаем, перезаписываем
nabor2=nabor2.drop(['two'],axis=1)
display(nabor2)
# Out:
#        record_id  locality_new
# 1              1        Шушары
# 6              6     Парголово
# 8              8        Мурино
# 20            20     Парголово
# 22            22       Кудрово
# ...          ...           ...
# 23645      23645   Елизаветино
# 23649      23649     Суходолье
# 23666      23666       Кудрово
# 23683      23683  Дзержинского
# 23696      23696   Рождествено
#
# [2821 rows x 2 columns]

# %%
#Набор 3

nabor3['locality_new'] = nabor3['three']
nabor3=nabor3.drop(['three'],axis=1)
display(nabor3)
# Out:
#        record_id locality_new
# 5              5      Янино-1
# 158          158      Янино-1
# 529          529      Янино-1
# 746          746      Янино-1
# 1121        1121      Янино-1
# ...          ...          ...
# 23048      23048       Лесное
# 23258      23258      Янино-1
# 23372      23372      Янино-1
# 23390      23390      Янино-1
# 23584      23584          Мга
#
# [189 rows x 2 columns]

# %%
#Набор 4
nabor4['locality_new'] = nabor4['four']
nabor4=nabor4.drop(['four'],axis=1)
display(nabor4)
# Out:
#        record_id   locality_new
# 88            88        Лебяжье
# 89            89      Сиверский
# 92            92  Кузьмоловский
# 139          139  Кузьмоловский
# 164          164     Ефимовский
# ...          ...            ...
# 23440      23440         Вырица
# 23480      23480          Рахья
# 23624      23624  Кузьмоловский
# 23651      23651        Токсово
# 23670      23670       Синявино
#
# [296 rows x 2 columns]

# %%
#Набор 5
nabor5['locality_new'] = nabor5['five']
nabor5=nabor5.drop(['five'],axis=1)
display(nabor5)
# Out:
#        record_id   locality_new
# 1594        1594      Свердлова
# 1819        1819       Морозова
# 2016        2016      Свердлова
# 2055        2055      Свердлова
# 2208        2208      Свердлова
# 2388        2388      Свердлова
# 2956        2956       Морозова
# 3125        3125      Свердлова
# 3178        3178       Морозова
# 3682        3682       Морозова
# 4252        4252       Морозова
# 4416        4416      Свердлова
# 4633        4633       Морозова
# 4844        4844       Морозова
# 5372        5372      Свердлова
# 7693        7693       Морозова
# 7760        7760       Морозова
# 8118        8118       Морозова
# 8148        8148      Свердлова
# 8229        8229      Свердлова
# 8240        8240      Свердлова
# 8432        8432      Свердлова
# 9512        9512         Вещево
# 9751        9751      Свердлова
# 9830        9830       Морозова
# 10210      10210      Свердлова
# 10405      10405       Морозова
# 10709      10709      Свердлова
# ...

# %%
display(nabor6) # пусто
display(nabor7) # пусто
display(nabor8)# пусто
display(nabor9)#пусто
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []

# %%
nabor10['locality_new'] = nabor10['four']+' '+ nabor10['five']
nabor10=nabor10.drop(['four','five'],axis=1)
display(nabor10)
# Out:
#        record_id   locality_new
# 37            37    Красный Бор
# 514          514    Красный Бор
# 3971        3971    Красный Бор
# 4772        4772    Красный Бор
# 6096        6096  Дружная Горка
# 7323        7323  Лесная Поляна
# 7685        7685  Дружная Горка
# 9544        9544    Красный Бор
# 12074      12074  Дружная Горка
# 12311      12311    Красный Бор
# 17305      17305  Большая Ижора
# 17689      17689  Дружная Горка
# 18045      18045  Дружная Горка
# 18903      18903    Красный Бор
# 21009      21009    Красный Бор

# %%
display(nabor11) # пусто
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []

# %%
nabor12['locality_new'] = nabor12['one'] +' '+ nabor12['two']
nabor12=nabor12.drop(['one','two'],axis=1)
display(nabor12)
# Out:
#        record_id   locality_new
# 182          182   Красное Село
# 249          249   Красное Село
# 306          306   Сосновый Бор
# 308          308   Красное Село
# 363          363   Красное Село
# ...          ...            ...
# 23368      23368   Красное Село
# 23392      23392  Лодейное Поле
# 23586      23586   Красное Село
# 23660      23660   Красное Село
# 23679      23679   Сосновый Бор
#
# [299 rows x 2 columns]

# %%
display(nabor13)#пусто
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []

# %%
nabor14.columns=['locality_new','record_id']
display(nabor14)
# Out:
#       locality_new  record_id
# 1097          drop       1097
# 2033          drop       2033
# 2603          drop       2603
# 2632          drop       2632
# 3574          drop       3574
# 4151          drop       4151
# 4189          drop       4189
# 4670          drop       4670
# 5343          drop       5343
# 5707          drop       5707
# 6765          drop       6765
# 7114          drop       7114
# 7330          drop       7330
# 7600          drop       7600
# 8568          drop       8568
# 8986          drop       8986
# 9821          drop       9821
# 10122         drop      10122
# 11248         drop      11248
# 12879         drop      12879
# 12936         drop      12936
# 13223         drop      13223
# 13690         drop      13690
# 14273         drop      14273
# 14342         drop      14342
# 15686         drop      15686
# 15866         drop      15866
# 16499         drop      16499
# 16561         drop      16561
# 16610         drop      16610
# ...

# %%
nabor15['locality_new'] = nabor15['two']+' '+ nabor15['three']+' '+ nabor15['four']
nabor15=nabor15.drop(['two','three','four'],axis=1)
display(nabor15)
# Out:
#        record_id           locality_new
# 10183      10183     Форт Красная Горка
# 19681      19681  Пансионат Зелёный Бор
# 19981      19981  Пансионат Зелёный Бор

# %%
display(nabor16)# пусто
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []

# %%
display(nabor17)#пусто
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []

# %%
display(nabor18)#пусто
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []

# %%
display(nabor19)#Пусто
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []

# %%
display(nabor20)# пусто
# Out:
# Empty DataFrame
# Columns: [one, two, three, four, five, record_id]
# Index: []

# %%
display(nabor21)
nabor21['locality_new'] = nabor21['two']+' '+ nabor21['three']
nabor21=nabor21.drop(['two','three'],axis=1)
display(nabor21)
# Out:
#             two      three  record_id
# 80        Новое  Девяткино         80
# 227       Новый       Свет        227
# 265       Новое  Девяткино        265
# 313       Новый       Свет        313
# 350       Новое  Девяткино        350
# ...         ...        ...        ...
# 23333     Малое     Верево      23333
# 23339     Новое  Девяткино      23339
# 23411  Борисова      Грива      23411
# 23510     Новое  Девяткино      23510
# 23698     Новый      Учхоз      23698
#
# [245 rows x 3 columns]
#        record_id     locality_new
# 80            80  Новое Девяткино
# 227          227       Новый Свет
# 265          265  Новое Девяткино
# 313          313       Новый Свет
# 350          350  Новое Девяткино
# ...          ...              ...
# 23333      23333     Малое Верево
# 23339      23339  Новое Девяткино
# 23411      23411   Борисова Грива
# 23510      23510  Новое Девяткино
# 23698      23698      Новый Учхоз
#
# [245 rows x 2 columns]

# %%
nabor22['locality_new'] = nabor22['three']+' '+ nabor22['four']
nabor22=nabor22.drop(['three','four'],axis=1)
display(nabor22)
# Out:
#        record_id     locality_new
# 101          101      Новая Ропша
# 1009        1009    Большая Ижора
# 1275        1275    Большая Ижора
# 2560        2560    Большая Ижора
# 3974        3974    Большая Ижора
# 6220        6220    Большая Ижора
# 9896        9896    Большая Ижора
# 10102      10102    Большая Ижора
# 12289      12289    Большая Ижора
# 13144      13144    Большая Ижора
# 15543      15543    Большая Ижора
# 15700      15700    Большая Ижора
# 16611      16611  Кивеннапа Север
# 18842      18842    Большая Ижора
# 19040      19040    Большая Ижора
# 20675      20675    Большая Ижора
# 20826      20826    Большая Ижора
# 21824      21824    Большая Ижора

# %% [markdown]
# Подготовили новые названия для строк, создаем столбец в исходном массиве df1 с названием locality_new, заполняем по record_id из наборов 1,2,3,4,5,10,12,14,15,21,22
# Предварительно, соеденим наборы в один большой набор и подумаем о прекрасном:)

# %%
test= pd.concat([nabor1, nabor2,nabor3,nabor4,nabor5,nabor10,nabor12,nabor14,nabor15,nabor21,nabor22])
#display(test)
test=test.sort_values(by='record_id',ascending=True)
display(test)
df1.shape
#display(test['locality_new'].value_counts(ascending=False))
# Out:
#           locality_new  record_id
# 0      Санкт-Петербург          0
# 1               Шушары          1
# 2      Санкт-Петербург          2
# 3      Санкт-Петербург          3
# 4      Санкт-Петербург          4
# ...                ...        ...
# 23694  Санкт-Петербург      23694
# 23695            Тосно      23695
# 23696      Рождествено      23696
# 23697  Санкт-Петербург      23697
# 23698      Новый Учхоз      23698
#
# [23699 rows x 2 columns]
# (23699, 23)

# %% [markdown]
# **Вывод:**
#
# Обнаруженные аномалии в данных, такие как последовательности из трех слов подряд и наличие табуляции, могут быть объяснены спецификой сбора данных. Скорее всего, сборка данных производится путем добавления нулей для формирования строки в формате "one, two, three, four, five". Это может быть следствием работы цикла, который включает в себя три значения: T (True), F (False) и 0, и выполняет сдвиг (заполнение нулями) в зависимости от условий.
#
# Примерная структура работы такого цикла выглядит следующим образом:
#
# FFFFF
# 0FFFF
# 00FFF
# 000FF
# 0000F
#
#
# Цикл последовательно перебирает каждую строку данных и добавляет нули в соответствии с условиями T (True), F (False) или 0, формируя строку в требуемом формате.

# %% [markdown]
# **Вывод:**
#
# В в процессе создания наборов данных, могли быть получены дополнительные качественные показатели, такие как село, посёлок городского типа (пгт) и другие.
# Эти данные могут быть использованы в дальнейшем анализе и исследованиях, хотя для решения текущей задачи они не потребовались. Для использования таких данных, возможно, потребуется модифицировать код, который извлекал наборы данных из `df` на основе определенных условий.

# %%
#Тестим на отдельном датафрейме
a=df.merge(test, on='record_id', how='outer')
suslik=a[a['locality_new'].isna()]
display(suslik)
#Соединяем оригинальный датафрейм df1 и тест
df1['record_id']=df1.index #создаем record_id в df1
df1=df1.merge(test, on='record_id', how='outer')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_сenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, record_id, locality_new]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Видишь суслика?(значения locality_name, которые не вошли в наборы)
#
# И я не вижу ;)

# %% [markdown]
# Как же хорошо, что нам поселки и посЁлки проверять не надо

# %%
display(test['locality_new'].value_counts(ascending=False))
# Out:
# Санкт-Петербург    15721
# Мурино               590
# Кудрово              472
# Шушары               440
# Всеволожск           398
#                    ...
# Пельгора               1
# Каложицы               1
# Платформа              1
# Почап                  1
# Дзержинского           1
# Name: locality_new, Length: 306, dtype: int64

# %% [markdown]
# Произведем обратную замену массива df на df1

# %%
#Cчитаем общее количество объявлений
print('Всего объявлений',df1['first_day_exposition'].count())
print('Уникальных дат в наборе объявлений',len(df1['first_day_exposition'].unique()))
# Out:
# Всего объявлений 23699
# Уникальных дат в наборе объявлений 1491

# %% [markdown]
# **Аномалия:**
#
# Все данные, включая числа с плавающей точкой, отображаются с точностью до 6 и 7 знаков после запятой, что, вероятно, является ошибкой форматирования. В данном контексте такая высокая точность не является необходимой и может затруднять анализ данных. Для целей анализа и удобства интерпретации, можно ограничить формат чисел до 0 знаков после запятой, так как доли сотых и тысячных частей, например, при измерении площадей или сумм, вероятно, не имеют значения.
#
# Эту аномалию можно решить путем округления чисел до целых значений или до формата с 0 знаками после запятой, за исключением координат, где высокая точность может быть важна.

# %%
display(df1.head(5))
# Out:
#    total_images   last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.000     108.000           2019-03-07      3
# 1             7  3350000.000      40.400           2018-12-04      1
# 2            10  5196000.000      56.000           2015-08-20      2
# 3             0 64900000.000     159.000           2015-07-24      3
# 4             2 10000000.000     100.000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0           2.700        16.000       51.000      8         0.000  ...
# 1          -1.000        11.000       18.600      1         0.000  ...
# 2          -1.000         5.000       34.300      4         0.000  ...
# 3          -1.000        14.000       -1.000      9         0.000  ...
# 4           3.030        14.000       32.000     13         0.000  ...
#
#      locality_name  airports_nearest  city_сenters_nearest  parks_around3000  \
# ...

# %% [markdown]
# Уберем отрицательные значения из столбцов, которые мы обработали

# %% [markdown]
# ## Вывод по разделу "Предобработка данных"
# **О замене пропущенных значений:**
#
# - `is_apartment` — апартаменты (булев тип) - пропуски- нулевые значения (заменяем нулями, меняем тип)
# - `parks_nearest` — расстояние до ближайшего парка (м) - Данные из автоматизированной системы, значит ближайший парк находится слишком далеко, заменяем пропущенные значения на (-1), т.к. при замене на 0 может исказиться картина
# - `ponds_nearest` — расстояние до ближайшего водоёма (м) - ближайший водоем находится слишком далеко, заменяем пропущенные значения на (-1), т.к. при замене на 0 может исказиться картина
# - `balcony` — число балконов. Переводим в int, заменяем на 0, т.к. это значит, что балконов нет
# - `ceiling_height` — высота потолков (м) - заменяем на -1 или на медианы по группам (число комнат, площадь, жилая площадь). Также можно исключить при анализе по данному критерию, поскольку, вероятно, заполняется пользователем, но пользователь может и не знать высоту
# - `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м) - заменяем на -1, т.к. вероятно, до ближайшего аэропорта слишком далеко
# - `cityCenters_nearest` — расстояние до центра города (м) - Видимо, данные с автоматической выгрузки, значит ближайший центр города находится слишком далеко, заменяем на -1
# - `ponds_around3000` — число водоёмов в радиусе 3 км - заменяем на -1
# - `parks_around3000` — число парков в радиусе 3 км - заменяем на -1
# - `days_exposition` — сколько дней было размещено объявление (от публикации до снятия) - заменяем на -1
# - `kitchen_area` — площадь кухни в квадратных метрах (м²) - либо дропаем, либо заменяем на -1
# - `living_area` — жилая площадь в квадратных метрах (м²) - либо дропаем, либо заменяем на -1
# - `floors_total` — всего этажей в доме - заменяем на -1
#
# *Для ответа на вопрос, почему заменяю на -1, а не нулями , во-первых- есть вероятность, что там уже есть значения, соотвествующие нулю, во вторых так как часть данных из автомат. системы можно будет определить на каком этапе они поломались, что с ними не так. Так как здесь используются вещественные числа*
#
# **О locality_name:**
#
# Большое количество неявных дубликатов так как классификатор состоит из признака (город, село. пгт) и названия.
#
# Причиной появления дубликатов является название объекта, формируемое засчет борка происходит за счет добавления нулей в формат вида one, two,three,four,five.
#
# Примерная структура цикла :имеет в себе 3 значения T,F,0 и делает сдвиг (заполняет нулями, если значение отсутствует, а также условием T(True) или F(False) Например: FFFFF 0FFFF 00FFF 000FF 0000F
#
# При этом он так перебирает каждую строку
#
# **О точности:**
#
# Все данные, в том числе в формате число с точкой отображаются с точностью 6 и 7 знаков после запятой, вероятно, ошибка форматирования.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
df1['price_per_m']=df1['last_price']/df1['total_area'] #цена квадратного метра
#день недели, месяц и год публикации объявления;
df1['pub_day']=df1['first_day_exposition'].dt.day
df1['pub_month']=df1['first_day_exposition'].dt.month
df1['pub_year']=df1['first_day_exposition'].dt.year

#этаж квартиры "floor_id"; варианты — первый, последний, другой;
display(df1.shape)
rows=(df1['floor']==1)&(df1['floor']==df1['floors_total'])
df1.loc[rows,"floor_id"]='первый'

rows=(df1['floor']!=1)|(df1['floor']!=df1['floors_total'])
df1.loc[rows,"floor_id"]='другой'

rows=(df1['floor']!=1)&(df1['floors_total']==df1['floor'])
df1.loc[rows,"floor_id"]='последний'
    
#соотношение жилой и общей площади, а также отношение площади кухни к общей.
df1['living_dev_total']=df1['living_area']/df1['total_area']
df1['kitchen_dev_total']=df1['kitchen_area']/df1['total_area']


#Прибавляем к дате first_date_exposition число дней показа из days_exposition через pd.to_timedelta -
#получаем дату продажи
df1['sell_to_date']=df1['first_day_exposition']+ pd.to_timedelta(df1['days_exposition'], unit='D')
# Out:
# (23699, 28)

# %% [markdown]
# ## Исследовательский анализ данных

# %%
# Изучите следующие параметры: площадь, цена, число комнат, высота потолков.
# Постройте гистограммы для каждого параметра.

# Площадь
print("Статистика по параметру 'total_area':")
display(df1['total_area'].describe())

plt.figure(figsize=(10, 5))
sns_plot1 = sns.boxplot(x=df1['total_area'])
sns_plot1.set_title('Гистограмма параметра "total_area"')
sns_plot1.set(xlim=(0, 115))  # Верхнее ограничение (1.5 размаха 25%-75%)
plt.show()
# Out:
# Статистика по параметру 'total_area':
# count   23699.000
# mean       60.349
# std        35.654
# min        12.000
# 25%        40.000
# 50%        52.000
# 75%        69.900
# max       900.000
# Name: total_area, dtype: float64

# %%
# Настройка формата отображения чисел
pd.options.display.float_format = '{:.4f}'.format 

# Цена
print("Статистика по параметру 'цена (в миллионах)'")
display((df1['last_price']/1000000).describe()) # 11.9 - Верхний предел

plt.figure(figsize=(10, 5))
sns_plot2 = sns.boxplot(x=df1['last_price']/1000000)
sns_plot2.set_title('Гистограмма параметра "цена (в миллионах)"')
sns_plot2.set(xlim=(0, 12))
plt.show()
# Out:
# Статистика по параметру 'цена (в миллионах)'
# count   23699.0000
# mean        6.5415
# std        10.8870
# min         0.0122
# 25%         3.4000
# 50%         4.6500
# 75%         6.8000
# max       763.0000
# Name: last_price, dtype: float64

# %% [markdown]
# **О Ценах**
#
#
# Цена в данной выборке была переведена в тысячи для удобства отображения, иначе значения сохраняли бы степень 10^8.
#
# При анализе структуры цен видно, что имеются выбросы, что вполне нормально для данных о ценах на недвижимость, так как цена может сильно варьироваться в зависимости от различных факторов.
#
#
# Большинство квартир находятся в диапазоне стоимости от 2.5 до 5.0 миллионов рублей, при этом квартир с очень высокой ценой значительно меньше.

# %%
#число комнат
display('число комнат')
display(df1['rooms'].describe())
sns_plot3 = sns.boxplot(x=df1['rooms'])
sns_plot3.set_title(
'Поле число комнат')
sns_plot3.set(xlim=(1,7))#Верхний предел 6
plt.show()
# Out:
# 'число комнат'
# count   23699.0000
# mean        2.0706
# std         1.0784
# min         0.0000
# 25%         1.0000
# 50%         2.0000
# 75%         3.0000
# max        19.0000
# Name: rooms, dtype: float64

# %% [markdown]
# **О числе комнат**
#
# По числу комнат присутсвуют нулевые значения,посмотрим, что там

# %%
display(df1[df1['rooms']==0])
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 144               1 2450000.0000     27.0000           2017-03-30      0
# 349               4 2320000.0000     25.0000           2017-09-27      0
# 440               8 2480000.0000     27.1100           2018-03-12      0
# 508               0 3375000.0000     34.4000           2017-03-28      0
# 608               2 1850000.0000     25.0000           2019-02-20      0
# ...             ...          ...         ...                  ...    ...
# 23210             7 3200000.0000     26.0000           2017-09-01      0
# 23442             0 2500000.0000     27.7000           2017-09-28      0
# 23554            15 3350000.0000     26.0000           2018-09-07      0
# 23592            10 1450000.0000     29.0000           2017-11-11      0
# 23637             8 2350000.0000     26.0000           2018-06-26      0
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# 197 значений, не много, можно удалить. В некоторых значениях присутсвуют пропуски практически по всем полям ( -1). Посмотрим, где

# %%
display(df1['locality_name'][df1['rooms']==0].value_counts())
# Out:
# Санкт-Петербург                            110
# посёлок Мурино                              27
# деревня Кудрово                             16
# Никольское                                   6
# Всеволожск                                   6
# Кудрово                                      5
# посёлок Шушары                               4
# посёлок Парголово                            4
# Сертолово                                    3
# посёлок Бугры                                2
# городской посёлок Новоселье                  2
# городской поселок Большая Ижора              1
# Отрадное                                     1
# поселок Бугры                                1
# городской посёлок Янино-1                    1
# деревня Новое Девяткино                      1
# поселок Новый Свет                           1
# поселок городского типа Дубровка             1
# Тосно                                        1
# посёлок Петро-Славянка                       1
# ...

# %% [markdown]
# Явной зависимости нет, но напоминает действие того же цикла, который мы обнаружили - убираем данные значения через условие, df1['rooms']>0

# %%
#число комнат
display('число комнат')
display(df1['rooms'].describe())
sns_plot3 = sns.histplot(x=df1['rooms'][df1['rooms']>0],kde=True)
sns_plot3.set_title(
'Поле число комнат,гистограмма')
#sns_plot3.set(xlim=(0,10))
plt.show()
# Out:
# 'число комнат'
# count   23699.0000
# mean        2.0706
# std         1.0784
# min         0.0000
# 25%         1.0000
# 50%         2.0000
# 75%         3.0000
# max        19.0000
# Name: rooms, dtype: float64

# %% [markdown]
# Количественно, число комнат показывает нам, что в нащем массиве примерно одинаковое
# однокомнатных и двухкомнатных квартир, на третьем месте  по количеству трехкомнатные квартиры

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Также мы можем увеличить сам график, чтобы его было удобнее изучать с помощью метода `plt.figure(figsize=(10,7))` или если используешь методы библиотеки `pandas`, в основном всегда есть атрибут `figsize=(10,7)`, который также поможет настроить ширину и высоту графика.
#
# </div>

# %% [markdown]
# По высоте потолков, в массиве присутствовали пропуски по данным значениям, убираем значения равные -1, а лучше все значения, меньше 2 м

# %%
#высота потолков
display('высота потолков')
display(df1['ceiling_height'][df1['ceiling_height']>=0].describe())
sns_plot4 = sns.barplot(x=df1['ceiling_height'][df1['ceiling_height']>=0])
sns_plot4.set_title(
'Поле высота потолков')
sns_plot4.set(xlim=(2,2.8)) #Оставим нижнее ограничение в 2м, верхнее 2.8
plt.show()
# Out:
# 'высота потолков'
# count   14504.0000
# mean        2.7715
# std         1.2611
# min         1.0000
# 25%         2.5200
# 50%         2.6500
# 75%         2.8000
# max       100.0000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Посмотрим, сколько значений

# %% [markdown]
# Квартир с потолками меньше 2х метров- 9209.Всего 75 квартир с потолками выше 4 метров.
# Больше всего квартир с высотой потолков от 2.4 до 3.5.

# %% [markdown]
# Рассмотрим время продажи квартиры.В данном поле присутсвовали пропуски, убираем значения равные -1,0

# %% [markdown]
# Верхний предел 159, нижний 0

# %%
display(df1[df1['days_exposition']>0])
# Out:
#        total_images    last_price  total_area first_day_exposition  rooms  \
# 1                 7  3350000.0000     40.4000           2018-12-04      1
# 2                10  5196000.0000     56.0000           2015-08-20      2
# 3                 0 64900000.0000    159.0000           2015-07-24      3
# 4                 2 10000000.0000    100.0000           2018-06-19      2
# 5                10  2890000.0000     30.4000           2018-09-10      1
# ...             ...           ...         ...                  ...    ...
# 23691            11  9470000.0000     72.9000           2016-10-13      2
# 23692             2  1350000.0000     30.0000           2017-07-07      1
# 23693             9  4600000.0000     62.4000           2016-08-05      3
# 23695            14  3100000.0000     59.0000           2018-01-15      3
# 23697            13 11475000.0000     76.7500           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# 20518 годных записей по полю 'days_exposition'

# %% [markdown]
# Увеличим масштаб

# %%
# время продажи квартиры 
display(df1['days_exposition'].describe())
sns_plot5 = sns.boxplot(x=df1['days_exposition'][df1['days_exposition']>0])
sns_plot5.set_title(
'Поле время продажи квартиры')
# верхний предел 464.5, нижний 0
#sns_plot5.set(xlim=(0,200))
plt.show()
# Out:
# count   23699.0000
# mean      156.4746
# std       213.6456
# min        -1.0000
# 25%        22.0000
# 50%        74.0000
# 75%       199.0000
# max      1580.0000
# Name: days_exposition, dtype: float64

# %% [markdown]
# **О времени продажи квартиры**
#
#
# Без учета аномальных значений время продажи постепенно снижается в зависимости от дней показа.
#
#
# Наибольшее количество проданных квартир наюлюдается в диапазоне 0-25 дней, также не совсем ясна причина пика.
#
# Боты? Автоматическая покупка ?

# %% [markdown]
# уменьшим формат

# %%
# время продажи квартиры 
#display(df1['days_exposition'].describe())
sns_plot5 = sns.histplot(x=df1['days_exposition'][df1['days_exposition']>0],kde=True)
sns_plot5.set_title(
'Поле days_exposition')
sns_plot5.set(xlim=(0,100))
plt.show()

# %% [markdown]
# Больше всего квартир продается в период показа объявления от 0 до 40 дней

# %% [markdown]
# Поле 'first_day_exposition'
# Построим частотную кривую количества объявлений по датам  тем же методом, как работали с locality_id

# %%
#display(df.info())

date_id= df1[['record_id','first_day_exposition']].sort_values(by='first_day_exposition',
                                                               ascending=True)
#display(date_id)

#Таблица индексов уникальных названий first_day_exposition  
date_index=date_id['first_day_exposition'].drop_duplicates().reset_index(drop=True)
#display(date_index)
date_index= pd.DataFrame(date_index)
date_index['date_id']=date_index.index
#display(date_index)
date_index['date_tag']=date_index['first_day_exposition']
#display(date_index)

#Мерджим по 'first_day_exposition'

date_id=date_id.merge(date_index, on='first_day_exposition', how='outer')
#display(date_id)
#дропаем 'first_day_exposition' из locality_id
date_id=date_id.drop(['first_day_exposition'],axis=1)
display(date_id)
# Out:
#        record_id  date_id   date_tag
# 0          10132        0 2014-11-27
# 1           8393        0 2014-11-27
# 2          15857        0 2014-11-27
# 3           2831        0 2014-11-27
# 4            696        0 2014-11-27
# ...          ...      ...        ...
# 23694      10917     1490 2019-05-03
# 23695       5986     1490 2019-05-03
# 23696       9217     1490 2019-05-03
# 23697      21887     1490 2019-05-03
# 23698      15072     1490 2019-05-03
#
# [23699 rows x 3 columns]

# %%
display(date_id)
display(df1)
df1=df1.merge(date_id, on='record_id', how='outer')
# Out:
#        record_id  date_id   date_tag
# 0          10132        0 2014-11-27
# 1           8393        0 2014-11-27
# 2          15857        0 2014-11-27
# 3           2831        0 2014-11-27
# 4            696        0 2014-11-27
# ...          ...      ...        ...
# 23694      10917     1490 2019-05-03
# 23695       5986     1490 2019-05-03
# 23696       9217     1490 2019-05-03
# 23697      21887     1490 2019-05-03
# 23698      15072     1490 2019-05-03
#
# [23699 rows x 3 columns]
#        total_images    last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.0000    108.0000           2019-03-07      3
# 1                 7  3350000.0000     40.4000           2018-12-04      1
# 2                10  5196000.0000     56.0000           2015-08-20      2
# 3                 0 64900000.0000    159.0000           2015-07-24      3
# 4                 2 10000000.0000    100.0000           2018-06-19      2
# ...

# %%
# расстояние от центра
#display(df1['days_exposition'].describe())
display(df1['city_сenters_nearest'].describe())
sns_plot15 = sns.boxplot(x=df1['city_сenters_nearest'][(df1['city_сenters_nearest']>=0)&
                                                      (df1['city_сenters_nearest']<=19509.75)])
sns_plot15.set_title(
'Поле city_centers_nearest')
# Верхний 19,509.75, нижний 0
#sns_plot5.set(xlim=(0,100))
plt.show()
# Out:
# count   23699.0000
# mean    10886.1940
# std      9634.8769
# min        -1.0000
# 25%      2242.0000
# 50%     11247.0000
# 75%     15248.5000
# max     65968.0000
# Name: city_сenters_nearest, dtype: float64

# %% [markdown]
# Верхний 19,509.75, нижний 0

# %%
top10_record_date=df1.pivot_table(index='date_id', values=['date_tag'],aggfunc=['count'])

# %%
top_10_record_date=df1.pivot_table(index='date_tag', values=['rooms'],aggfunc=['count'])
top_10_record_date=top_10_record_date.sort_values(by='date_tag',ascending=True)
display(top_10_record_date.plot())
top_10_record_date.columns=['record_cc']
top_10_record_date['date']=top_10_record_date.index
top_10_record_date['date']=pd.to_datetime(top_10_record_date['date'], format='%Y-%m-%dT%H:%M:%S')
display(top_10_record_date['record_cc'].describe())
sns11=sns.boxplot(x=top_10_record_date['record_cc'])
sns11.set_title(
'Поле число объявлений в сутки')
sns11.set(xlim=(0,56.5))# По числу объявлений в сутки оставим верхнее ограничение  56.5
# Out:
# <AxesSubplot:xlabel='date_tag'>
# count   1491.0000
# mean      15.8947
# std       18.3153
# min        1.0000
# 25%        4.0000
# 50%       10.0000
# 75%       25.0000
# max      368.0000
# Name: record_cc, dtype: float64
# [(0, 56.5)]

# %% [markdown]
# Наибольшее количество публикаций по дате пришлось на период между 2017-07 - 2018-07

# %% [markdown]
# Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра.

# %%
#зависит ли цена от площади, числа комнат, удалённости от центра.

total_area=df1[(df1['total_area']>=0)&(df1['total_area']<=114.75)] #114,75

last_price=df1[(df1['last_price']/1000000)<=11.9] # Верхний предел


rooms=df1[(df1['rooms']<=6)&(df1['rooms']>=1)]

ceiling_height=df1[(df1['ceiling_height']<=2.8)&(df1['ceiling_height']>=2)]#Оставим нижнее ограничение в 2м, верхнее 2.8


# Верхний 19,509.75, нижний 0
city_сenters_nearest=df1[(df1['city_сenters_nearest']>=0)&
                        (df1['city_сenters_nearest']<=19509.75)]

display('total_area')
display(total_area[['last_price', 'total_area', 'rooms','city_сenters_nearest','ceiling_height']
                  ].corr())

display('last_price')
display(last_price[['last_price', 'total_area', 'rooms',
                    'city_сenters_nearest','ceiling_height']].corr())
display('rooms')
display(rooms[['last_price', 'total_area', 'rooms','city_сenters_nearest','ceiling_height']].corr())


display('ceiling_height')
display(ceiling_height[['last_price', 'total_area', 'rooms',
                        'city_сenters_nearest','ceiling_height']].corr())

display('city_сenters_nearest')
display(city_сenters_nearest[['last_price', 'total_area', 'rooms',
                        'city_сenters_nearest','ceiling_height']].corr())


#Корелляционная таблица
#pd.options.display.float_format = '{:.4f}'.format # Точнее 
#stat_multi= df1.pivot_table(index='record_id', values=['last_price', 'total_area', 'rooms','city_сenters_nearest'])
#display(stat_multi)
# Out:
# 'total_area'
#                       last_price  total_area   rooms  city_сenters_nearest  \
# last_price                1.0000      0.6817  0.3856                0.0184
# total_area                0.6817      1.0000  0.7892               -0.0350
# rooms                     0.3856      0.7892  1.0000               -0.0189
# city_сenters_nearest      0.0184     -0.0350 -0.0189                1.0000
# ceiling_height            0.0968      0.0750  0.0702                0.0262
#
#                       ceiling_height
# last_price                    0.0968
# total_area                    0.0750
# rooms                         0.0702
# city_сenters_nearest          0.0262
# ceiling_height                1.0000
# 'last_price'
#                       last_price  total_area   rooms  city_сenters_nearest  \
# last_price                1.0000      0.6982  0.4529                0.1066
# total_area                0.6982      1.0000  0.8034               -0.0161
# ...

# %% [markdown]
# В результате анализа зависимостей между различными параметрами можно сделать следующие выводы:
#
# - `total_area` зависит от `last_price` с коэффициентом корреляции 0.7 и от `rooms` с коэффициентом корреляции 0.8. Это означает, что площадь квартиры имеет сильную положительную зависимость от её цены и числа комнат.
#
# - `total_area` не зависит от `city_centers_nearest` (коэффициент корреляции близок к нулю, 0.0) и имеет слабую положительную зависимость от `ceiling_height` с коэффициентом корреляции 0.1.
#
# - `last_price` зависит от `total_area` с коэффициентом корреляции 0.7, что говорит о сильной положительной зависимости цены от общей площади квартиры.
#
# - `last_price` не зависит от `rooms` (коэффициент корреляции 0.5), что означает, что число комнат не имеет такого сильного влияния на цену (по данному единичному критерию). Также, `last_price` не зависит от `city_centers_nearest` (коэффициент корреляции 0.1) и `ceiling_height` (коэффициент корреляции 0.1).
#
# - `rooms` зависит от `total_area` с коэффициентом корреляции 0.7, что указывает на сильную положительную зависимость числа комнат от общей площади квартиры.
#
# - `rooms` не зависит от `last_price` (коэффициент корреляции 0.4), `city_centers_nearest` (коэффициент корреляции близок к нулю, 0.0) и имеет слабую положительную зависимость от `ceiling_height` с коэффициентом корреляции 0.1.
#
# - `ceiling_height` не зависит от `last_price` (коэффициент корреляции 0.2), `total_area` (коэффициент корреляции 0.2), `rooms` (коэффициент корреляции 0.1) и `city_centers_nearest` (коэффициент корреляции близок к нулю, 0.0).
#
# - `city_centers_nearest` не зависит от `last_price` (коэффициент корреляции -0.3), `total_area` (-0.4), `rooms` (-0.3) и имеет слабую отрицательную зависимость от `ceiling_height` (-0.1).
#
# Эти выводы позволяют лучше понять взаимосвязи между различными параметрами в данных о недвижимости.

# %% [markdown]
# Строим графики зависимостей, для вывода о наличии взаимосвязей

# %%
display('total_area')
pd.plotting.scatter_matrix(total_area[['last_price', 'total_area', 
                           'rooms','city_сenters_nearest','ceiling_height']
                  ], figsize=(9, 9))
plt.show()

display('last_price')
pd.plotting.scatter_matrix(last_price[['last_price', 'total_area', 'rooms',
                    'city_сenters_nearest','ceiling_height']
                                     ], figsize=(9, 9))
plt.show()

display('rooms')
pd.plotting.scatter_matrix(rooms[['last_price', 'total_area', 'rooms',
                                  'city_сenters_nearest','ceiling_height']
                                ], figsize=(9, 9))
plt.show()

display('ceiling_height')
pd.plotting.scatter_matrix(ceiling_height[['last_price', 'total_area', 'rooms',
                        'city_сenters_nearest','ceiling_height']
                                         ], figsize=(9, 9))
plt.show()

display('city_сenters_nearest')
pd.plotting.scatter_matrix(city_сenters_nearest[['last_price', 'total_area',
                                                 'rooms','city_сenters_nearest',
                                                 'ceiling_height']
                            ], figsize=(9, 9))
plt.show()
# Out:
# 'total_area'
# 'last_price'
# 'rooms'
# 'ceiling_height'
# 'city_сenters_nearest'

# %%
#Проверяем взаимосвязь last_price и days_exposition

display('last_price')
display(last_price[['last_price', 'days_exposition']].corr())
# Out:
# 'last_price'
#                  last_price  days_exposition
# last_price           1.0000           0.0538
# days_exposition      0.0538           1.0000

# %%
#Проверяем взаимосвязь last_price и days_exposition

display('last_price')
display(last_price[['last_price', 'days_exposition']].corr())
# Out:
# 'last_price'
#                  last_price  days_exposition
# last_price           1.0000           0.0538
# days_exposition      0.0538           1.0000

# %% [markdown]
# ***Вывод по графикам зависимостей `last_price`, `total_area`, `rooms`, и `city_centers_nearest`:***
#
# - Чем ближе к центру города, тем выше цена на недвижимость. Наибольшие значения цены наблюдаются в диапазоне от нуля до 10 км от центра, а затем наблюдается постепенное снижение цены с увеличением расстояния от центра. Эта зависимость нелинейна, что означает, что каждый дополнительный километр от центра снижает цену на недвижимость в меньшей степени, чем предыдущий.
#
# - Самые дорогие квартиры обычно имеют 3, 4 или 5 комнат, в то время как самые дешевые - это 1 и 2 комнатные квартиры. Это подтверждает, что количество комнат оказывает влияние на цену недвижимости.
#
# - Большинство квартир в выборке имеют до 5 комнат. Это также подтверждает, что в большинстве случаев владельцы предпочитают квартиры с небольшим количеством комнат.
#
# - Площадь квартиры и расстояние от центра города имеют обратную зависимость в данной выборке. Это означает, что чем дальше от центра, тем меньше общая площадь квартир. Однако стоит отметить, что выборка в основном состоит из квартир с площадью до 250 квадратных метров.
#
# Эти наблюдения помогают понять, какие факторы влияют на цену и характеристики недвижимости в данной выборке.

# %%
locality_id= df1[['record_id','locality_new']].sort_values(by='locality_new',ascending=True)

#Таблица индексов уникальных названий locality_new 
locality_index=locality_id['locality_new'].drop_duplicates().reset_index(drop=True)

locality_index=locality_index.str.split('\t',expand=True)
locality_index.columns=['locality_new']
locality_index['id']=locality_index['locality_new'].index
locality_index['loc_tag']=locality_index['locality_new']

#Мерджим по locality_new

locality_id=locality_id.merge(locality_index, on='locality_new', how='outer')

#дропаем 'locality_new' из locality_id
locality_id=locality_id.drop(['locality_new'],axis=1)
display(locality_id)
# Out:
#        record_id   id  loc_tag
# 0          16561    0     drop
# 1          14273    0     drop
# 2          12936    0     drop
# 3          22474    0     drop
# 4          19045    0     drop
# ...          ...  ...      ...
# 23694       8015  305  Янино-1
# 23695      21028  305  Янино-1
# 23696       4970  305  Янино-1
# 23697      21766  305  Янино-1
# 23698       7468  305  Янино-1
#
# [23699 rows x 3 columns]

# %%
df1=df1.merge(locality_id, on='record_id', how='outer')

# %%
display(df1.head(3))
# Out:
#    total_images    last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.0000    108.0000           2019-03-07      3
# 1             7  3350000.0000     40.4000           2018-12-04      1
# 2            10  5196000.0000     56.0000           2015-08-20      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0          2.7000       16.0000      51.0000      8        0.0000  ...
# 1         -1.0000       11.0000      18.6000      1        0.0000  ...
# 2         -1.0000        5.0000      34.3000      4        0.0000  ...
#
#    pub_month  pub_year  floor_id  living_dev_total kitchen_dev_total  \
# 0          3      2019    другой            0.4722            0.2315
# 1         12      2018    другой            0.4604            0.2723
# 2          8      2015    другой            0.6125            0.1482
#
#    sell_to_date  date_id   date_tag   id          loc_tag
# 0    2019-03-06     1433 2019-03-07  224  Санкт-Петербург
# ...

# %% [markdown]
# **10 населённых пунктов с наибольшим числом объявлений.**

# %%
top10_record=df1.pivot_table(index=df1['record_id'],values=['loc_tag'],aggfunc=['sum','count'])
top10_record.columns=['loc_tag','records_cc']
top10_record=top10_record.groupby(['loc_tag']).agg({'records_cc':'sum'}).sort_values(by='records_cc',ascending=False).head(10)
display('Лидеры по числу публикаций:')
display(top10_record)
# Out:
# 'Лидеры по числу публикаций:'
#                  records_cc
# loc_tag
# Санкт-Петербург       15721
# Мурино                  590
# Кудрово                 472
# Шушары                  440
# Всеволожск              398
# Пушкин                  369
# Колпино                 338
# Парголово               327
# Гатчина                 307
# Выборг                  237

# %%
intrest_tag=['Санкт-Петербург', 'Мурино', 'Кудрово', 'Шушары', 'Всеволожск',
       'Пушкин', 'Колпино', 'Парголово', 'Гатчина', 'Выборг']
#Разбили на категории по loc_tag+pivot
intrest_tag = pd.DataFrame(intrest_tag)

spb_stat=df1[df1['loc_tag']=='Санкт-Петербург'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
spb_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']

murino_stat=df1[df1['loc_tag']=='Мурино'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
murino_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']

kudrovo_stat=df1[df1['loc_tag']=='Кудрово'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
kudrovo_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']


shushari_stat=df1[df1['loc_tag']=='Шушары'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
shushari_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']


vsevolojsk_stat=df1[df1['loc_tag']=='Всеволожск'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
vsevolojsk_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']


pushkin_stat=df1[df1['loc_tag']=='Пушкин'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
pushkin_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']

kolpino_stat=df1[df1['loc_tag']=='Колпино'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
kolpino_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']

parglovo_stat=df1[df1['loc_tag']=='Парголово'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
parglovo_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']

gatchina_stat=df1[df1['loc_tag']=='Гатчина'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
gatchina_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']

viborg_stat=df1[df1['loc_tag']=='Выборг'].pivot_table(index='loc_tag',values=['last_price','price_per_m','living_dev_total'],aggfunc=['count','mean'])
viborg_stat.columns=['count_last_price','count_living_dev_total','count_price_per_m','mean_last_price','mean_living_dev_total','mean_price_per_m']

# %% [markdown]
# Сшиваем характеристики по интересующим городам в один датафрейм

# %%
#Сшиваем в один
stats_topten_complete=pd.concat([spb_stat,murino_stat,kudrovo_stat,shushari_stat,vsevolojsk_stat,pushkin_stat,
kolpino_stat,parglovo_stat,gatchina_stat,viborg_stat])

# %%
stats_topten_complete=stats_topten_complete.sort_values(by='mean_price_per_m',ascending=False).drop(['count_last_price','count_living_dev_total'],axis=1)
stats_topten_complete.columns=['Количество объявлений','Средняя цена продажи','Среднее соотношение жилой площади/общей площади','Средняя цена квадратного метра']

# %%
display(stats_topten_complete)
# Out:
#                  Количество объявлений  Средняя цена продажи  \
# loc_tag
# Санкт-Петербург                  15721          8062507.0686
# Пушкин                             369          6469035.9458
# Кудрово                            472          4358688.0508
# Парголово                          327          4488074.7982
# Мурино                             590          3678462.2034
# Шушары                             440          4108081.8159
# Колпино                            338          3964021.4379
# Гатчина                            307          3488336.6775
# Всеволожск                         398          3789067.7513
# Выборг                             237          3250983.1224
#
#                  Среднее соотношение жилой площади/общей площади  \
# loc_tag
# Санкт-Петербург                                           0.5234
# Пушкин                                                    0.5243
# Кудрово                                                   0.4521
# ...

# %% [markdown]
# **Вывод**
#
# Выгоднее всего покупать квартиру в Выборге,Всеволожске, Гатчине и Колпино соотношение цена квадратного метра и соотношение жилой к обшей площади.

# %% [markdown]
# Рассмотрим характеристики по СПб

# %%
#Проверяем взаимосвязь last_price и days_exposition для СПБ
 
display('last_price_spb')
last_price_spb=last_price[last_price['locality_name']=='Санкт-Петербург']
display(last_price_spb[['last_price','days_exposition']].corr())

display('last_price_spb')
pd.plotting.scatter_matrix(last_price_spb[['last_price', 'days_exposition']]
                           , figsize=(9, 9)) 
plt.show()
# Out:
# 'last_price_spb'
#                  last_price  days_exposition
# last_price           1.0000           0.0795
# days_exposition      0.0795           1.0000
# 'last_price_spb'

# %%
df1['city_сenters_nearest_km']=df1['city_сenters_nearest']/1000 #добавили в исходный массив поле  расстояние в км
df1['price_per_km_from_city_center']=df1['last_price']/df1['city_сenters_nearest_km']



spb_sub_stat=df1[df1['loc_tag']=='Санкт-Петербург'].pivot_table(index='record_id',values=['city_сenters_nearest','last_price','price_per_m','rooms','price_per_km_from_city_center','city_сenters_nearest_km'],aggfunc=['count','mean'])
spb_sub_stat=spb_sub_stat.drop(['count'],axis=1)

# %%
spb_sub_stat.columns=['city_сenters_nearest','city_сenters_nearest_km',
                      'last_price','price_per_km_from_city_center',
                      'price_per_m','rooms']
display(spb_sub_stat)
# Out:
#            city_сenters_nearest  city_сenters_nearest_km    last_price  \
# record_id
# 0                    16028.0000                  16.0280 13000000.0000
# 2                    13933.0000                  13.9330  5196000.0000
# 3                     6800.0000                   6.8000 64900000.0000
# 4                     8098.0000                   8.0980 10000000.0000
# 7                    11634.0000                  11.6340  7915000.0000
# ...                         ...                      ...           ...
# 23689                16081.0000                  16.0810  3550000.0000
# 23690                 6263.0000                   6.2630  5500000.0000
# 23691                 4489.0000                   4.4890  9470000.0000
# 23694                 4232.0000                   4.2320  9700000.0000
# 23697                10364.0000                  10.3640 11475000.0000
#
#            price_per_km_from_city_center  price_per_m  rooms
# record_id
# ...

# %% [markdown]
# Лучше классифицировать по количеству комнат, расстоянию до центра, чем по стоимости так как количество комнат = константа, а стоимость var.
#
# Строим график, сортируем данные по расстоянию от центра города в км

# %%
spb_sub_stat['city_сenters_nearest_km'].sort_values(ascending=True).hist().set_title(
'Гистограмма распределение количество объявлений в зависимости отрасстояния  центра города')
plt.show()

# %% [markdown]
# Больше всего объявлений в диапазоне от 0 до 15 км, потом число объявлений снижается

# %% [markdown]
# Масштабируем от 0 до 15

# %%
spb_sub_stat['city_сenters_nearest_km'].sort_values(ascending=True).hist(bins=10,range=(0,5)).set_title(
'Гистограмма распределение количество объявлений в зависимости отрасстояния  центра города')
plt.show()

# %% [markdown]
# Еще увеличим масштаб

# %%
spb_sub_stat['city_сenters_nearest_km'].sort_values(ascending=True).hist(bins=10,range=(0,2)).set_title(
'Гистограмма распределение количество объявлений в зависимости отрасстояния  центра города')
plt.show()

# %% [markdown]
# Интересующие нас значения по Петербургу (центр города лежит в диапазоне от 0,
# до 1.25 км включительно),
# исключение составляют значения -1 км, так как ранее мы суловились, что с ними что-то не так, исключаем их из финальной выборки по условию ниже:

# %%
#Так как ранее мы уже извлекли критерии, применяем их к выборке по СПБ
display(last_price_spb[['city_сenters_nearest']].describe())

sns_spb1=sns.boxplot(x=last_price_spb['city_сenters_nearest']).set_title(
'Распределение расстояния от  центра города')
#sns11.set(xlim=(0,56.5))# По числу объявлений в сутки оставим верхнее ограничение  56.5
# Out:
#        city_сenters_nearest
# count            13763.0000
# mean             12190.9235
# std               4624.3095
# min                 -1.0000
# 25%               9649.0000
# 50%              12702.0000
# 75%              15176.0000
# max              29493.0000

# %% [markdown]
# Поступаем как и в предыдущей ситуации, задаем нижний интервал 0, верхний 1.5 размаха 25%, 75% + значение 75%, то есть 23466.5

# %%
#Так как ранее мы уже извлекли критерии, применяем их к выборке по СПБ
display(last_price_spb[['city_сenters_nearest']].describe())

sns_spb1=sns.boxplot(x=last_price_spb['city_сenters_nearest'])
sns_spb1.set_title(
'Расстояние от  центра города')
sns_spb1.set(xlim=(0,23466.5))
# Out:
#        city_сenters_nearest
# count            13763.0000
# mean             12190.9235
# std               4624.3095
# min                 -1.0000
# 25%               9649.0000
# 50%              12702.0000
# 75%              15176.0000
# max              29493.0000
# [(0.0, 23466.5)]

# %%
display('Весь СПБ')
pre_centr_spb=last_price_spb[(last_price_spb['city_сenters_nearest']>=0)&
                             (last_price_spb['city_сenters_nearest']<=23466.5)]
pre_centr_spb['city_сenters_nearest_km']=pre_centr_spb[
    'city_сenters_nearest']/1000
#Прайс от расстояния по всему СПБ
pre_centr_spb['last_price']=pre_centr_spb['last_price']/1000000 #в миллионах
sns.kdeplot(pre_centr_spb['city_сenters_nearest_km'],pre_centr_spb['last_price'],
            cmap = 'Reds',shade = True,shade_lowest=False).set_title(
'Зависимость  цена/расстояние по всему СПб')
plt.show()

sns.histplot(x=pre_centr_spb['city_сenters_nearest_km'],y=pre_centr_spb['last_price'],legend=True).set_title(
'Зависимость  цена/расстояние по всему СПб')
plt.show()
#sns_spb2.set(xlim=(0,23466.5))
# Out:
# 'Весь СПБ'

# %%
#Центр СПБ
display(pre_centr_spb['city_сenters_nearest_km'].describe())
pre_centr_spb.plot(kind='scatter',x='city_сenters_nearest_km',
                   y='last_price').set(xlim=(0,1.5))


plt.show()

centr_spb=pre_centr_spb
centr_spb['city_сenters_nearest_km_rounded']=round(centr_spb['city_сenters_nearest_km'])
display('Центр СПб')



sns.kdeplot(centr_spb['city_сenters_nearest_km_rounded'],centr_spb['last_price'],
            cmap = 'Reds', shade = True,shade_lowest=False
           ).set_title(
'Зависимость  цена/расстояние по СПб, видны максимумы')
plt.show()
sns.histplot(x=centr_spb['city_сenters_nearest_km_rounded'],y=centr_spb['last_price'],
                      ).set_title(
'Зависимость  цена/расстояние центр СПб')
plt.show()
#display(last_price[['last_price', 'days_exposition']].corr())
# Out:
# count   13602.0000
# mean       12.1110
# std         4.4248
# min         0.2080
# 25%         9.6500
# 50%        12.6770
# 75%        15.1310
# max        23.3650
# Name: city_сenters_nearest_km, dtype: float64
# 'Центр СПб'

# %% [markdown]
# Как видно из графика last_price как критерий не подошел, но все-равно видно,
# что у нас есть локальный максимум на участке от 0 до 10 км от центра СПб
# проверяем  критерий city_centers_nearest

# %%
#display(city_сenters_nearest.info())
display(city_сenters_nearest['city_сenters_nearest'].describe())
# Out:
# count   15480.0000
# mean    11351.0559
# std      4507.7447
# min       181.0000
# 25%      8256.0000
# 50%     12167.0000
# 75%     14855.0000
# max     19501.0000
# Name: city_сenters_nearest, dtype: float64

# %% [markdown]
# Собственно, уже по describe видно, что данный критерий по полю city_сenters_nearest лучше. Почему  о критериях ничего нет в лекционных материалах?

# %% [markdown]
# Что мы делаем сейчас, правильно, показываем первый локальный максимум
# по критерию city_сenters_nearest_km

# %%
spb_sub_stat=spb_sub_stat[(spb_sub_stat['city_сenters_nearest_km']<=1.25)&
                     (spb_sub_stat['city_сenters_nearest_km']>=0)]

# %% [markdown]
# Распределение цена- расстояние от центра в км с красивым графиком

# %%
final=spb_sub_stat.sort_values(by='city_сenters_nearest_km').pivot_table(index=spb_sub_stat.index,values=['city_сenters_nearest_km','last_price'],aggfunc='mean')
display(final)

final['last_price']=final['last_price']/1000000 #в миллионах
a=sns.kdeplot(final['city_сenters_nearest_km'],final['last_price'],
            cmap = 'Reds', shade = True,shade_lowest=False)
a.set_title(
'Зависимость  цена/расстояние центр СПб')
plt.show()
# Out:
#            city_сenters_nearest_km    last_price
# record_id
# 213                         0.1810 31099000.0000
# 433                         0.2080  5800000.0000
# 492                         0.2150 10990000.0000
# 502                         0.2870  9590000.0000
# 660                         0.2910 11500000.0000
# ...                            ...           ...
# 22831                       1.2400 23900000.0000
# 22904                       1.2420  3800000.0000
# 23005                       1.2480  8250000.0000
# 23400                       1.2490  5450000.0000
# 23648                       1.2500 13800000.0000
#
# [148 rows x 2 columns]

# %% [markdown]
# В результате анализа данных графиков можно выделить несколько интересных наблюдений:
#
# **Весь Санкт-Петербург:**
# - Графики "Зависимость цена/расстояние весь СПб" и "Зависимость цена/расстояние весь СПб, увеличен масштаб" показывают, что цены на недвижимость варьируются в зависимости от расстояния от центра города. Ближе к центру цены выше, а с увеличением расстояния цены постепенно снижаются.
#
# **Санкт-Петербург, диапазон 0.6 - 0.8 км:**
# - Для этого сегмента также наблюдается зависимость цен от расстояния. Однако здесь центральная зона ближе к 0.7 км от центра.
#
# **Разделение на три пояса:**
# - Анализ данных позволяет классифицировать "центр" на три пояса: до 5 км, от 5 км до 10 км и от 10 км до 20+ км.
# - Графики показывают, что в каждом из этих поясов наблюдаются различия в ценах на недвижимость. Например, цены в самом центре (до 5 км) обычно выше, чем в других поясах.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Супер, здорово что подтвердили эту информацию на основе наших данных 🔥
# </div>

# %% [markdown]
# Изучаем сегмент квартир в центре по СПБ

# %%
#меняем точность
pd.options.display.float_format = '{:.1f}'.format

# %%
#Сегмент квартир в центре СПБ
centr_spb1=df1[(df1['city_сenters_nearest_km']<=1.25)&
               (df1['loc_tag']=='Санкт-Петербург')&
               (df1['city_сenters_nearest_km']>=0)
              ]
centr_spb1=centr_spb1[['last_price', 'total_area', 'rooms','city_сenters_nearest']]
#График для исследование зависимости 'last_price', 'total_area', 'rooms','city_сenters_nearest'
#По центру СПБ
pd.plotting.scatter_matrix(centr_spb1, figsize=(9, 9)) 
plt.show()
#График для исследование зависимости 'last_price','pub_month','pub_day','pub_year'
#По центру СПБ
centr_spb2=df1[(df1['city_сenters_nearest_km']<=1.25)&
               (df1['loc_tag']=='Санкт-Петербург')&
               (df1['city_сenters_nearest_km']>=0)
              ]
#График для исследование зависимости 'last_price','pub_month','pub_day','pub_year'
#По центру СПБ
centr_spb2=centr_spb2[['last_price','pub_month','pub_day','pub_year']]
pd.plotting.scatter_matrix(centr_spb2, figsize=(9, 9)) 
plt.show()

# %% [markdown]
# По СПБ
#
# Давайте проанализируем зависимость параметра 'last_price' от других параметров для недвижимости в Санкт-Петербурге:
#
# **По 'last_price' в диапазоне от 0 до 150 миллионов:**
# - Наибольшие значения 'last_price' количественно наблюдаются в диапазоне до 0.5 миллионов.
# - Присутствует корреляция между 'last_price' и 'total_area' в диапазоне по 'total_area' до 150 квадратных метров. Это означает, что цена недвижимости обычно растет с увеличением общей площади квартиры.
# - Также наблюдается постепенное возрастание цены ('last_price') при увеличении количества комнат ('rooms').
# - Зависимость цены от расстояния до центра города ('city_centers_nearest') видна до 25 километров, после этого расстояния корреляция становится незначительной.
#
# **По 'pub_day' (день публикации):**
# - Количество публикаций растет от 0 до 10 дней, после чего остается стабильным до 20 дней, а затем начинает снижаться.
#
# **По 'pub_year' (год публикации):**
# - Число публикаций постепенно росло до 2018 года, а затем начало снижаться.
#
# **По 'pub_month' (месяц публикации):**
# - Количество публикаций примерно одинаково до декабря, а в декабре происходит резкий скачок.
#
# Эти наблюдения могут помочь понять, какие факторы влияют на цену недвижимости в Санкт-Петербурге и как они коррелируют с другими параметрами.

# %%
#По всей выборке
display('по всей выборке')
total_df1=df1[['last_price', 'total_area', 'rooms','city_сenters_nearest']]

#График для исследование зависимости 'last_price', 'total_area', 'rooms','city_сenters_nearest'
#По всей выборке
pd.plotting.scatter_matrix(total_df1, figsize=(9, 9)) 
plt.show()
#График для исследование зависимости 'last_price','pub_month','pub_day','pub_year'
#По всей выборке
total_df2=df1[['last_price','pub_month','pub_day','pub_year']]

#График для исследование зависимости 'last_price','pub_month','pub_day','pub_year'
#По всей выборке
pd.plotting.scatter_matrix(total_df2, figsize=(9, 9)) 
plt.show()
# Out:
# 'по всей выборке'

# %% [markdown]
# Добавим поле с датой продажи квартиры:
# (дата публикации + число дней публикации)
# sell_to_date

# %%
#График для исследование зависимости sell_to_date
#Повсей выборке
sell_to_date_all=df1

sell_to_date_all['first_day_exposition'].value_counts().plot(legend=True)

display(sell_to_date_all['sell_to_date'].describe())
sell_to_date_all['sell_to_date'].value_counts().plot(legend=True).set_title(
'Зависимость  sell_to_date/first_day_exposition по всей выборке')
plt.show()
# Out:
# count                   23699
# unique                   1132
# top       2018-01-23 00:00:00
# freq                      492
# first     2014-11-26 00:00:00
# last      2019-05-02 00:00:00
# Name: sell_to_date, dtype: object

# %%
#По СПб
sell_to_date_spb=df1[(df1['loc_tag']=='Санкт-Петербург')]

sell_to_date_spb['first_day_exposition'].value_counts().plot(legend=True)

display(sell_to_date_spb['sell_to_date'].describe())
sell_to_date_spb['sell_to_date'].value_counts().plot(legend=True).set_title(
'Зависимость  sell_to_date/first_day_exposition по СПб')
plt.show()
# Out:
# count                   15721
# unique                   1097
# top       2018-01-23 00:00:00
# freq                      265
# first     2014-11-26 00:00:00
# last      2019-05-02 00:00:00
# Name: sell_to_date, dtype: object

# %%
#По центру СПб
sell_to_date_centr_spb=df1[(df1['city_сenters_nearest_km']<=1.25)&
               (df1['loc_tag']=='Санкт-Петербург')&
               (df1['city_сenters_nearest_km']>=0)]

sell_to_date_centr_spb['first_day_exposition'].value_counts().plot(legend=True)

display(sell_to_date_centr_spb['sell_to_date'].describe())
sell_to_date_centr_spb['sell_to_date'].value_counts().plot(legend=True).set_title(
'Зависимость  sell_to_date/first_day_exposition по центру СПб')
plt.show()
# Out:
# count                     148
# unique                    130
# top       2018-10-30 00:00:00
# freq                        3
# first     2015-01-14 00:00:00
# last      2019-05-01 00:00:00
# Name: sell_to_date, dtype: object

# %% [markdown]
# ## Вывод по разделу "Исследовательский Анализ данных"
#
# **Выделенные наблюдения позволяют сделать следующие выводы:**
#
# 1. Квартиры, которые были выставлены на продажу в период с января 2015 года по июль 2016 года, не пользовались активным спросом на рынке недвижимости. В этот период можно отметить низкую активность продаж.
#
# 2. После июля 2016 года начался более активный период продаж недвижимости. Это может быть связано с изменениями в рыночных условиях, экономическими факторами или другими обстоятельствами, которые способствовали увеличению спроса на недвижимость.
#
# 3. Наблюдается рассинхрон между временем размещения объявления о продаже и фактическим временем продажи. Однако с течением времени этот рассинхрон уменьшается, что может указывать на более стабильные интервалы продажи недвижимости.
#
# 4. В данном массиве объявлений о продаже квартир на первом этаже крайне мало, всего 25 штук. В Петербурге преимущественно встречаются квартиры на других этажах или на последних этажах.
#
# 5. В центре Петербурга также наблюдается предпочтение квартир на других этажах или последних этажах, возможно, из-за туристической активности в этой части города..
#
# Эти наблюдения могут быть полезными для анализа долгосрочных тенденций на рынке недвижимости и для принятия решений о выставлении квартиры на продажу в определенный временной период.

# %% [markdown]
# # Итоговый Вывод
#
# В исходном массиве данных о продаже квартир в Санкт-Петербурге содержится 23699 строк и 23 столбца. Явных дубликатов в данных не обнаружено.
#
# Важно отметить, что в некоторых столбцах присутствуют пропущенные значения, которые были заменены следующим образом:
#
# - `is_apartment` (апартаменты) — пропуски были заменены нулевыми значениями (тип данных изменен на булев тип).
# - `parks_nearest` (расстояние до ближайшего парка) и `ponds_nearest` (расстояние до ближайшего водоема) — пропущенные значения были заменены на -1, так как данные получены из автоматизированной системы и ближайшие парки и водоемы могут находиться слишком далеко, и замена на 0 исказила бы картину.
# - `balcony` (число балконов) — был переведен в целочисленный формат и пропущенные значения были заменены на 0, что означает отсутствие балконов.
# - `ceiling_height` (высота потолков) — пропущенные значения были заменены на -1 или медианные значения в группах (число комнат, площадь, жилая площадь). Этот столбец также можно исключить из анализа, так как высота потолков может быть неизвестной для пользователей.
# - `airports_nearest` (расстояние до ближайшего аэропорта) и `cityCenters_nearest` (расстояние до центра города) — пропущенные значения были заменены на -1, так как предположительно ближайшие аэропорты и центр города находятся слишком далеко.
# - `ponds_around3000` (число водоемов в радиусе 3 км) и `parks_around3000` (число парков в радиусе 3 км) — пропущенные значения были заменены на -1.
# - `days_exposition` (сколько дней было размещено объявление) — пропущенные значения были заменены на -1.
# - `kitchen_area` (площадь кухни) и `living_area` (жилая площадь) — пропущенные значения были заменены на -1.
# - `floors_total` (всего этажей в доме) — пропущенные значения были заменены на -1.
#
# Замена на -1 была выбрана, чтобы отличить пропущенные значения от нулевых и обозначить их как "неизвестные". Такой подход также позволяет легче выявить и анализировать данные, которые могли быть повреждены в процессе сбора.
#
# Также были проведены анализы зависимостей между различными параметрами, включая цену, площадь, количество комнат и расстояние до центра города. Выводы из анализа:
#
# - Цена зависит от расстояния до центра города нелинейно, с наибольшими значениями цены в диапазоне от нуля до 10 км от центра.
# - Самые дорогие квартиры имеют 3, 4 или 5 комнат.
# - Большинство квартир в выборке имеют до 5 комнат.
# - Площадь квартир обратно пропорциональна расстоянию до центра, чем дальше от центра, тем меньше общая площадь.
# - В центре Санкт-Петербурга цена квартир выше, и она также зависит от площади, количества комнат и расстояния до центра.
#
# Исходя из анализа, можно выделить основные характеристики рынка недвижимости в Санкт-Петербурге, а также различия между центром и остальной частью города. Кроме того, было обнаружено, что объявления о продаже квартир на первом этаже крайне редки, а в центре города предпочтение отдается квартирам на других этажах или на последних этажах.
#
# Результаты этого анализа могут быть полезны для определения факторов, влияющих на цену недвижимости, и для принятия более обоснованных решений при покупке или продаже недвижимости в Санкт-Петербурге.

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [X]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
